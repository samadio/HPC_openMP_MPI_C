# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dim=[1,2,4,8,16,20,40]
results=[61.814760,31.925568,15.878107,8.427509,4.500832,3.590915,1.791862]

ax = subplot(111)
ax.plot(dim, results,linewidth=1)
ax.set_xlabel('number of threads')
ax.set_ylabel('time (sec)')
#plt.savefig("time.png",dpi=200)
plt.show()
